# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.head()
# Out:
#           a         b         c         d
# 0  0.433065  0.229132  0.483934  0.279395
# 1  0.565721  0.275158  0.029005  0.250673
# 2  0.844185  0.973158  0.827822  0.485329
# 3  0.556652  0.433945  0.825294  0.096314
# 4  0.001687  0.432828  0.489905  0.554722

# %%
# 데이터를 누적 영역 차트 형태로 시각화
df.plot.area()
# Out:
# <Axes: >

# %%
# 데이터 누적 해제
df.plot.area(stacked=False, grid=True)
# Out:
# <Axes: >
