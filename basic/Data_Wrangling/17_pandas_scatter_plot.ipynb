# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(50, 4) , columns=['a', 'b', 'c', 'd'])

df.head()
# Out:
#           a         b         c         d
# 0  0.942097  0.033669  0.124332  0.549727
# 1  0.772053  0.942104  0.664416  0.160300
# 2  0.631098  0.768493  0.309583  0.787183
# 3  0.564515  0.435457  0.437722  0.926500
# 4  0.766049  0.376796  0.028304  0.836268

# %%
# s=10: 점의 크기
df.plot.scatter(x='a', y='b', s=10, grid=True)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkRed', label='Group 1')
df.plot.scatter(x='c', y='d', color='DarkBlue', label='Group 2', ax=ax)
# Out:
# <Axes: xlabel='c', ylabel='d'>

# %%
# c='c': 'c'라는 컬럼의 값을 기준으로 점의 색상을 결정
df.plot.scatter(x='a', y='b', c='c', s=50)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x='a', y='b', s=df['c'] * 200)
# Out:
# <Axes: xlabel='a', ylabel='b'>
