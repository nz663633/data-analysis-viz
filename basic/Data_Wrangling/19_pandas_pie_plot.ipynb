# %% [markdown]
# ### Pie plot
# - Seaborn에서는 파이차트 지원 X

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# Jupyter Notebook 에 그래프 표시를 위해
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
# a, b, c, d 인덱스 생성
# 3 * np.random.rand(4): 0 이상 1 미만의 난수 4개 생성 후 각각 3을 곱함
series = pd.Series(3 * np.random.rand(4),
                   index=['a', 'b', 'c', 'd'], name='series')

# %%
series
# Out:
# a    1.056471
# b    2.263187
# c    0.568574
# d    1.942719
# Name: series, dtype: float64

# %%
# figsize=(6, 6): 생성되는 그래프의 전체 크기 설정
series.plot.pie(figsize=(6, 6))
# Out:
# <Axes: >

# %%
# colors=['r', 'g', 'b', 'c']: Matplotlib 시각화 라이브러리에서 정해진 기본 색상 약자
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'],
                colors=['r', 'g', 'b', 'c'],
                autopct='%.2f',
                fontsize=20,
                figsize=(6, 6))
# Out:
# <Axes: >

# %%
# y='mass': 'mass' 컬럼의 데이터를 기준으로 파이차트 생성
df = pd.DataFrame({'mass': [0.330, 4.87, 5.97],
                   'radius': [2439.7, 6051.8, 6378.1]},
                   index=['Mercury', 'Venus', 'Earth'])
plot = df.plot.pie(y='mass', figsize=(5, 5))

# %%
df
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
# subplots=True: 데이터프레임 안에 있는 모든 숫자 열을 별도의 그래프로 그리기
plot = df.plot.pie(subplots=True, figsize=(10,5))
