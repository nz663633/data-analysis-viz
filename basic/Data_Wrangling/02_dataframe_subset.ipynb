# %%
import sys
print(sys.executable)

# %%
import pandas as pd
import seaborn as sns

# %%
# Seaborn 라이브러리에서 iris 데이터 가져오기
df = sns.load_dataset("iris")
df.head()

# %%
# 특정 컬럼들 가져오기(여러 개인 경우 list로 묶어서)
df[['sepal_width', 'sepal_length', 'species']]

# %%
columns = ['sepal_width', 'sepal_length', 'species']
df[columns].head()

# %%
df.sepal_width

# %%
# 정규표현식(regex)로 '_'가 들어간 컬럼들을 추출
df.filter(regex='_')

# %%
df.filter(regex='length$')

# %%
df.loc[:, 'sepal_width':'petal_width']

# %%
df.iloc[:5, [1,3]]

# %%
df.loc[df['sepal_length'] > 3, ['sepal_length', 'sepal_width']]
