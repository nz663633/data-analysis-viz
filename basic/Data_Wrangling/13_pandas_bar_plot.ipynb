# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))
ts.head()
# Out:
# 2000-01-01    0.558490
# 2000-01-02    0.261699
# 2000-01-03   -0.488003
# 2000-01-04    1.403273
# 2000-01-05   -1.127027
# Freq: D, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))
df.head(6)
# Out:
#                    A         B         C         D
# 2000-01-01 -1.173301 -1.102565 -1.420968 -0.503124
# 2000-01-02  0.303641  2.045737 -1.014436 -1.520585
# 2000-01-03  0.035370 -0.794306 -2.519632 -0.792905
# 2000-01-04 -0.977050 -1.933897 -1.593197  0.010478
# 2000-01-05 -0.549524  0.647533 -0.174476  0.566492
# 2000-01-06  2.381633  0.563351 -1.535866  0.844289

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2002-09-25  1.369709 -0.630470  1.565355  0.365610
# 2002-09-26 -0.117744 -0.637442 -1.493736 -1.139189

# %%
df.iloc[5]
# Out:
# A    2.381633
# B    0.563351
# C   -1.535866
# D    0.844289
# Name: 2000-01-06 00:00:00, dtype: float64

# %%
df.iloc[5].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[5].plot.bar()

# plt.axhline(): 가로로 직선(수평선)을 긋는 함수(0: 수평선을 그릴 y축의 위치)
plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4),
                   columns=['a', 'b', 'c', 'd'])

df2.head(3)
# Out:
#           a         b         c         d
# 0  0.690623  0.077768  0.858357  0.516150
# 1  0.956658  0.468346  0.684214  0.601116
# 2  0.602801  0.884678  0.163308  0.546450

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
# bar(stacked=True): 각 열의 데이터를 위로 쌓아서 표현(누적 막대그래프)
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
# barh(): x축과 y축 변환(horizontal)
df2.plot.barh(stacked=True)
# Out:
# <Axes: >
